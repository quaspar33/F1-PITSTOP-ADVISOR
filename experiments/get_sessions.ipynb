# %%
from shared_ibraries import gather_data, 
from datetime import datetime

import pickle

# %%
sessions = gather_data.get_sessions(datetime.now())
# Out:
# Analizuję rok 2022...
# Znaleziono 19 wyścigów dla roku 2022
#   Pobieram dane dla wyścigu: Bahrain Grand Prix (Runda 1)
#   Pobieram dane dla wyścigu: Saudi Arabian Grand Prix (Runda 2)
#   Pobieram dane dla wyścigu: Australian Grand Prix (Runda 3)
#   Pobieram dane dla wyścigu: Miami Grand Prix (Runda 5)
#   Pobieram dane dla wyścigu: Spanish Grand Prix (Runda 6)
#   Pobieram dane dla wyścigu: Monaco Grand Prix (Runda 7)
#   Pobieram dane dla wyścigu: Azerbaijan Grand Prix (Runda 8)
#   Pobieram dane dla wyścigu: Canadian Grand Prix (Runda 9)
#   Pobieram dane dla wyścigu: British Grand Prix (Runda 10)
#   Pobieram dane dla wyścigu: French Grand Prix (Runda 12)
#   Pobieram dane dla wyścigu: Hungarian Grand Prix (Runda 13)
#   Pobieram dane dla wyścigu: Belgian Grand Prix (Runda 14)
#   Pobieram dane dla wyścigu: Dutch Grand Prix (Runda 15)
#   Pobieram dane dla wyścigu: Italian Grand Prix (Runda 16)
#   Pobieram dane dla wyścigu: Singapore Grand Prix (Runda 17)
# ...

# %%
loaded_sessions = gather_data.load_sessions(sessions)
# Out:
# [2022 Season Round 1: Bahrain Grand Prix - Race,
#  2022 Season Round 2: Saudi Arabian Grand Prix - Race,
#  2022 Season Round 3: Australian Grand Prix - Race,
#  2022 Season Round 5: Miami Grand Prix - Race,
#  2022 Season Round 6: Spanish Grand Prix - Race,
#  2022 Season Round 7: Monaco Grand Prix - Race,
#  2022 Season Round 8: Azerbaijan Grand Prix - Race,
#  2022 Season Round 9: Canadian Grand Prix - Race,
#  2022 Season Round 10: British Grand Prix - Race,
#  2022 Season Round 12: French Grand Prix - Race,
#  2022 Season Round 13: Hungarian Grand Prix - Race,
#  2022 Season Round 14: Belgian Grand Prix - Race,
#  2022 Season Round 15: Dutch Grand Prix - Race,
#  2022 Season Round 16: Italian Grand Prix - Race,
#  2022 Season Round 17: Singapore Grand Prix - Race,
#  2022 Season Round 18: Japanese Grand Prix - Race,
#  2022 Season Round 19: United States Grand Prix - Race,
#  2022 Season Round 20: Mexico City Grand Prix - Race,
# ...

# %%
with open("./sessions.pkl", "wb") as file:
    pickle.dump(sessions, file)
